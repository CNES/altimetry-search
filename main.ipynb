# %% [markdown]
# # Search SWOT passes

# %%
from search_swot import MapSelection
MapSelection().display()

# %%
import search_swot

# %%
search_swot?

# %%
import numpy
import pyinterp.core.geometry.geographic as geographic

# %%
lons = [2,5,5,2,2]
lats = [2,2,5,5,2]

# %%
poly = geographic.Polygon(
    geographic.Ring(
        numpy.array(lons, dtype=numpy.float64),
        numpy.array(lats, dtype=numpy.float64),
    )
)

# %%
poly.outer

# %%
import pyinterp.TemporalAxis
